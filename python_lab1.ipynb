# %% [markdown]
# # This is the next python lab for SI200
# Remember to RENAME this file (click on the python_lab1.ipynb name above) before you begin! It should look like this:
#
# python_lab1_*malpha*.ipynb
#
# **Keep the ".ipynb"!!**
#
# Use <code>File->Save</code> often!
#
# ## Read everything in this notebook or you are likely to miss important info!

# %% [markdown]
# <h1>Remember to execute these first two cells!</h1>
# And take a look at the contents of this cell by clicking on the text! <b>Look familiar?</b>
# This is markdown text... similar to something you <em>should</em> recognize now!
#
# To exit the cell you can type <code>Shift-Enter</code>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# The following cell loads the libraries you'll need to complete the lab.

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %% [markdown]
# The below genfromtxt call, in the numpy library -- see above, works for our tab delimted data set. However, you can add the parameter to the genfromtxt function call that specifies the delimiter. You could look at this file in your google drive to determine what that delimiter is! Add it and make sure it still works.
#
# The *names=True* parameter tells genfromtxt to use the column headers as names for the various fields in the data.
#
# Note how we needed the "delimiter=..." parameter for the comma seperated values in the Computers.csv dataset. This parameter tells genfromtxt what to expect between values in the data file.

# %%
studentData = np.genfromtxt("/content/drive/My Drive/Colab Notebooks/StudentInfo.txt",names=True)

# %%
compData = np.genfromtxt("/content/drive/My Drive/Colab Notebooks/Computers.csv",names=True,delimiter=',')

# %% [markdown]
# ## Explore the data
# Look at the studentData and compData variables in the cells below

# %%
studentData

# %%
compData

# %% [markdown]
# Note the labels for the data at the bottom.

# %% [markdown]
# ## Code in the cell below
# Generate a scatter plot price. Remember, you need an x value for every 'price'. How will you generate a list of numbers? Hint: remember our friends len() and range()?

# %% [markdown]
# Ok... that probably wasn't too useful, lets reorganize the data to make the scatter plot more useful. Let's sort the data.<br>
# Numpy arrays have a built in sort. Use help(compData.sort) to get some
# info. We can use the default, so after getting help, you can just <code>compData.sort()</code> to sort by the first column, price

# %%
help(compData.sort)

# %%
compData.sort()

# %% [markdown]
# Now that you've sorted the data by price (in place -- i.e. compData has been changed!), go ahead and re-run the scatter plot

# %% [markdown]
# Use the student dataset. Plot a histogram of scores.

# %% [markdown]
# Now plot the histogram and ensure the bins correspond to the letter grades A-D within the usual ranges (90-100 A, etc.)

# %% [markdown]
# Ok... now plot just the first 100 rows of the price data. You can use a variable to store those prices, or just access and print them all in one go like we did in class!

# %% [markdown]
# Now try the same for the <b>last</b> 100 items in the screen data column. You may have to goggle "how to access the end of a numpy array".

# %% [markdown]
# Now just have some fun with the data. Change the marker style and color. Try this for all 3 plot types: scatter, plot and hist.

# %% [markdown]
# Save this notebook and share it with your instructor.
